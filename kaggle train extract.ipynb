# %%
# !pip install fire
# !pip install retry
# !pip install torch_optimizer

# %%
cd /kaggle/working/

# %%
# !rm -rf /kaggle/working/CustomStyleGAN

# %%
# !git clone https://github.com/HuangYin0514/CustomStyleGAN.git

# %%
cd CustomStyleGAN/

# %%
# !cp /kaggle/input/checkpoint/model_10.pt /kaggle/working/CustomStyleGAN/

# %%
# !python main.py --data '/kaggle/input/celeba-dataset/img_align_celeba/img_align_celeba/'   --num_train_steps 120001 --load_from 10

# %%
# !tar zcf GoodResult.tar GoodResult/

# %%
# !tar zcf  ../image_results.tar GoodResult/results/
# !tar zcf  ../logs.tar GoodResult/logs/
# !cp -rf GoodResult/models ../

# %%
cd ../

# %%
# !rm -rf /kaggle/working/CustomStyleGAN
